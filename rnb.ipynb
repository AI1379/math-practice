# %%
x <- seq(from = -pi, to = pi, length.out = 1000)
y <- sin(x)
plot(x, y,
    type = "l", col = "blue", lwd = 2,
    xlab = "x", ylab = "sin(x)",
    main = "Plot of sin(x) from -π to π",
)
grid()
# Out:
# Plot with title "Plot of sin(x) from -π to π"
